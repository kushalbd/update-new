# %%
import requests
page1 = requests.get("https://en.wikipedia.org/wiki/Main_Page")
print(page1.status_code)#request to the Wikipedia main page was successful
print(page1.content)
# Out:
# 200
# ...
